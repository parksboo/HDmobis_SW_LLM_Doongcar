# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## **Private token!!**

# %%
# private
import os
# private
def load_env():
    with open('.env', 'r') as f:
        for line in f:
            if line.strip():  # 빈 줄이 아닌 경우만 처리
                key, value = line.strip().split('=')
                os.environ[key] = value

load_env()
ACCESS_TOKEN = os.getenv('HUGGINGFACE_TOKEN')

# %%
# !huggingface-cli login --token $ACCESS_TOKEN --add-to-git-credential
# Out:
# Token is valid (permission: read).
# Cannot authenticate through git-credential as no helper is defined on your machine.
# You might have to re-authenticate when pushing to the Hugging Face Hub.
# Run the following command in your terminal in case you want to set the 'store' credential helper as default.
#
# git config --global credential.helper store
#
# Read https://git-scm.com/book/en/v2/Git-Tools-Credential-Storage for more details.
# Token has not been saved to git credential helper.
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
# !pip install pytorch==1.13.1
# !pip install torchvision==0.14.1
# !pip install torchaudio==0.13.1
# !pip install transformers
# !pip install git+https://github.com/huggingface/accelerate
# !pip install rouge-score
# Out:
# ERROR: Could not find a version that satisfies the requirement pytorch==1.13.1 (from versions: 0.1.2, 1.0.2)
# ERROR: No matching distribution found for pytorch==1.13.1
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.2/24.2 MB 69.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 887.5/887.5 MB 2.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.3/849.3 kB 63.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 557.1/557.1 MB 2.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.1/317.1 MB 3.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.0/21.0 MB 70.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: torch
#     Found existing installation: torch 2.1.0+cu121
#     Uninstalling torch-2.1.0+cu121:
#       Successfully uninstalled torch-2.1.0+cu121
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.16.0+cu121
#     Uninstalling torchvision-0.16.0+cu121:
# ...

# %%
import os
os.chdir('/content/drive/MyDrive')
# !git clone https://github.com/ArmelRandy/self-instruct
os.chdir('./self-instruct')
# Out:
# fatal: destination path 'self-instruct' already exists and is not an empty directory.

# %%
# !accelerate launch main.py --seed_tasks_path="data/seed_tasks.jsonl" --output_data_path data/output.jsonl --num_instructions_to_generate 1 --template_name better --format 2 --model_name_or_path="bigcode/starcoderbase-1b" --num_prompt_instructions 8 --request_batch_size 8 --num_prompt_synthetic_instructions 2 --max_new_tokens 4096 --temperature 0.8 --top_p 0.95 --num_beams 1 --repetition_penalty 1.2 --threshold 0.7 --seed 42 --keep_programming
# Out:
# The following values were not passed to `accelerate launch` and had defaults used instead:
# 	`--num_processes` was set to a value of `1`
# 	`--num_machines` was set to a value of `1`
# 	`--mixed_precision` was set to a value of `'no'`
# 	`--dynamo_backend` was set to a value of `'no'`
# To avoid this warning pass in values for each of the problematic parameters or run `accelerate config`.
# Loaded 8 human-written seed instructions.
#   0% 0/1 [00:00<?, ?it/s]
# 0it [00:00, ?it/s]/usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:392: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.8` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# ...
